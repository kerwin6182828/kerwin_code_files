# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python

#load packages
import sys #access to system parameters https://docs.python.org/3/library/sys.html
print("Python version: {}". format(sys.version))

import pandas as pd #collection of functions for data processing and analysis modeled after R dataframes with SQL like features
print("pandas version: {}". format(pd.__version__))

import matplotlib #collection of functions for scientific and publication-ready visualization
print("matplotlib version: {}". format(matplotlib.__version__))

import numpy as np #foundational package for scientific computing
print("NumPy version: {}". format(np.__version__))

import scipy as sp #collection of functions for scientific computing and advance mathematics
print("SciPy version: {}". format(sp.__version__)) 

import IPython
from IPython import display #pretty printing of dataframes in Jupyter notebook
print("IPython version: {}". format(IPython.__version__)) 

import sklearn #collection of machine learning algorithms
print("scikit-learn version: {}". format(sklearn.__version__))

#misc libraries
import random
import time


#ignore warnings
import warnings
warnings.filterwarnings('ignore')
print('-'*25)
# Out:
# Python version: 3.6.0 (v3.6.0:41df79263a11, Dec 23 2016, 08:06:12) [MSC v.1900 64 bit (AMD64)]
# pandas version: 0.23.4
# matplotlib version: 3.0.1
# NumPy version: 1.15.3
# SciPy version: 1.1.0
# IPython version: 7.1.1
# scikit-learn version: 0.20.0
# -------------------------

# %%
l1 = pd.read_csv("l1.csv", encoding="gb18030")
l2 = pd.read_csv("l2.csv",encoding="gb18030")
l1.estate = l1.district + l1.estate

# %%
l1.orientation.isnull().sum()
# Out:
# 2

# %%
d = pd.DataFrame(np.random.randint(1, 10, (4, 3)))
print(d.dtypes)
dd = pd.concat([d,d], axis=1)
print(dd.dtypes)
d = d.append([3, 4, 5])
d.dtypes
# Out:
# 0    int32
# 1    int32
# 2    int32
# dtype: object
# 0    int32
# 1    int32
# 2    int32
# 0    int32
# 1    int32
# 2    int32
# dtype: object
# 0      int64
# 1    float64
# 2    float64
# dtype: object

# %%
d[0][d[0]==2] = np.nan

# %%
d[0].dtype
# Out:
# dtype('float64')

# %%
d.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# dtype: object

# %%
d[0][d[0]=="nan"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-5787be54e6bd> in <module>
# ----> 1 d[0][d[0]=="nan"]
#
# c:\users\administrator\appdata\local\programs\python\python36\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
#    1284             if is_scalar(res):
#    1285                 raise TypeError('Could not compare {typ} type with Series'
#
# c:\users\administrator\appdata\local\programs\python\python36\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1167                     result = method(y)
#    1168                 if result is NotImplemented:
# -> 1169                     raise TypeError("invalid type comparison")
#    1170             else:
#    1171                 result = op(x, y)
#
# ...

# %%
d[0].isnull()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 0    False
# 1     True
# 2    False
# Name: 0, dtype: bool

# %%
d[0][3]=0

# %%
print(d[0][3])
# Out:
# nan

# %%
d[0].dtype
# Out:
# dtype('float64')

# %%
pd.DataFrame(d[0], dtype="object")[0]
# Out:
# 0    NaN
# 1      3
# 2      1
# 3      0
# 0      3
# 1    NaN
# 2      5
# Name: 0, dtype: object

# %%
d
# Out:
#      0    1    2
# 0  NaN  NaN  NaN
# 1  3.0  1.0  5.0
# 2  1.0  2.0  8.0
# 3  0.0  NaN  NaN
# 0  3.0  NaN  NaN
# 1  NaN  NaN  NaN
# 2  5.0  NaN  NaN

# %%
d[0][3] = None

# %%
d[0].isnull()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 0    False
# 1     True
# 2    False
# Name: 0, dtype: bool

# %%
d
# Out:
#      0    1    2
# 0  NaN  NaN  NaN
# 1  3.0  1.0  5.0
# 2  1.0  2.0  8.0
# 3  NaN  NaN  NaN
# 0  3.0  NaN  NaN
# 1  NaN  NaN  NaN
# 2  5.0  NaN  NaN

# %%
l1.metro.unique()
# Out:
# array(['暂无数据', '距地铁1号线(临平-湘湖)西湖文化广场1101米', '距地铁1号线(临平-湘湖)西湖文化广场564米', ...,
#        '距地铁1号线(临平-湘湖)西湖文化广场714米', '距地铁1号线(临平-湘湖)打铁关340米',
#        '距地铁2号线中河北路522米'], dtype=object)

# %%
l1.metro[l1.metro == "暂无数据"] = None
for i, j in enumerate(l1.metro[l1.metro.notnull()]):
    print(i, type(j))
#     l1.metro.iloc[i]
# Out:
# 0 <class 'str'>
# 1 <class 'str'>
# 2 <class 'str'>
# 3 <class 'str'>
# 4 <class 'str'>
# 5 <class 'str'>
# 6 <class 'str'>
# 7 <class 'str'>
# 8 <class 'str'>
# 9 <class 'str'>
# 10 <class 'str'>
# 11 <class 'str'>
# 12 <class 'str'>
# 13 <class 'str'>
# 14 <class 'str'>
# 15 <class 'str'>
# 16 <class 'str'>
# 17 <class 'str'>
# 18 <class 'str'>
# 19 <class 'str'>
# 20 <class 'str'>
# 21 <class 'str'>
# 22 <class 'str'>
# 23 <class 'str'>
# 24 <class 'str'>
# 25 <class 'str'>
# 26 <class 'str'>
# 27 <class 'str'>
# 28 <class 'str'>
# 29 <class 'str'>
# 30 <class 'str'>
# 31 <class 'str'>
# 32 <class 'str'>
# 33 <class 'str'>
# 34 <class 'str'>
# 35 <class 'str'>
# 36 <class 'str'>
# 37 <class 'str'>
# 38 <class 'str'>
# 39 <class 'str'>
# 40 <class 'str'>
# 41 <class 'str'>
# 42 <class 'str'>
# 43 <class 'str'>
# 44 <class 'str'>
# 45 <class 'str'>
# 46 <class 'str'>
# 47 <class 'str'>
# 48 <class 'str'>
# 49 <class 'str'>
# 50 <class 'str'>
# 51 <class 'str'>
# 52 <class 'str'>
# ...

# %%
type(l1.metro[l1.metro.notnull()])
# Out:
# pandas.core.series.Series

# %%
l1.metro.head()
# Out:
# 0                        None
# 1                        None
# 2    距地铁1号线(临平-湘湖)西湖文化广场1101米
# 3                        None
# 4     距地铁1号线(临平-湘湖)西湖文化广场564米
# Name: metro, dtype: object

# %%
import re

# %%
l1.metro[l1.metro.notnull()].apply(foo )
# Out:
# 2        6
# 4        3
# 14       4
# 18       6
# 22       1
# 25       6
# 28       5
# 29       6
# 30       3
# 35       5
# 37       3
# 38       5
# 41       6
# 42       1
# 43       6
# 47       2
# 51       3
# 52       4
# 56       4
# 61       4
# 62       2
# 63       5
# 64       5
# 65       3
# 70       3
# 71       2
# 73       3
# 74       4
# 79       5
# 82       6
#         ..
# 13153    4
# 13154    6
# 13159    2
# 13160    6
# 13163    6
# 13166    5
# 13167    6
# 13172    4
# 13173    5
# 13174    2
# 13175    3
# 13176    5
# 13182    4
# 13184    4
# 13192    4
# 13194    4
# 13195    4
# 13196    4
# 13199    4
# 13200    6
# 13204    6
# 13207    6
# 13208    5
# 13212    2
# 13216    5
# 13221    4
# 13223    4
# 13224    2
# 13228    3
# 13234    3
# Name: metro, Length: 4389, dtype: int64

# %%
def foo_1(x):
    if int(x) <= 200:
        return 1
    elif 200 < int(x) <= 400:
        return 2
    elif 400 < int(x) <= 600:
        return 3
    elif 600 < int(x) <= 800:
        return 4
    elif 800 < int(x) <= 1000:
        return 5
    elif 1000 < int(x) <= 1200:
        return 6

# %%
xx = None

# %%
int(xx)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-37410c2aebec> in <module>
# ----> 1 int(xx)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %%
if int("3")<=44:
    print(9)
# Out:
# 9

# %%
a = 1
if a == 3

# %%
l1.metro[l1.metro.notnull()] = l1.metro[l1.metro.notnull()].apply(lambda x: re.findall(r"(\d+)米", x)[0])

# %%
dd = pd.DataFrame(np.random.randint(1, 10, (7, 4)))
dd
# Out:
#    0  1  2  3
# 0  3  6  8  4
# 1  4  7  1  5
# 2  7  4  8  2
# 3  2  8  7  7
# 4  6  5  8  8
# 5  9  3  5  9
# 6  2  5  7  7

# %%
dd.sort_values(by=2, axis=1)
# Out:
#    3  1  0  2
# 0  4  6  3  8
# 1  5  7  4  1
# 2  2  4  7  8
# 3  7  8  2  7
# 4  8  5  6  8
# 5  9  3  9  5
# 6  7  5  2  7

# %%
dd[0].sort_values(ascending=False)
# Out:
# 5    9
# 2    7
# 4    6
# 1    4
# 0    3
# 6    2
# 3    2
# Name: 0, dtype: int32

# %%
def foo_2(x):
    print(type(x))
    pass
#     print(x)
#     if "东" in x:
#         x["dong"] = 1
#         print(x)
#         return x
    
l1["orientation"].apply(foo_2)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
for i, j in enumerate(l1):
    print(j)
# Out:
# building_start_year
# district
# estate
# house_id
# housing_area
# metro
# orientation
# price
# rental_mode
# rooms
# shi
# ting
# title
# total_floor
# wei
# zone

# %%
l_d = []
l_n = []
l_x = []
l_b = []

for i in l1.orientation:
    print(type(i))
    if "东" in i:
        l_d.append(1)
    else:
        l_d.append(0)
    if "南" in i:
        l_n.append(1)
    else:
        l_n.append(0)
    if "西" in i:
        l_x.append(1)
    else:
        l_x.append(0)
    if "北" in i:
        l_b.append(1)
    else:
        l_b.append(0)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
np.array(l_b).sum()
# Out:
# 452

# %%
for i in l1.orientation.unique():
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
l1.orientation.isnull().sum()
# Out:
# 2

# %%
dd["dd"]=[1, 2, 3, 4, 5, 6, 7]

# %%
dd
# Out:
#    0  1  2  3  4  dd
# 0  3  6  8  4  1   1
# 1  4  7  1  5  2   2
# 2  7  4  8  2  3   3
# 3  2  8  7  7  4   4
# 4  6  5  8  8  5   5
# 5  9  3  5  9  6   6
# 6  2  5  7  7  7   7

# %%
def foo_2(y):
    def foo_22(x):
        if "东" in x:
            retrun ""
    if y.name == "orientation":
        y.name.apply(foo_22)
    else:    
        return y

    
l1 = l1.apply(foo_2)
# Out:
# 0        2012
# 1        2009
# 2          板楼
# 3        2013
# 4        1985
# 5        2012
# 6        1989
# 7        2010
# 8        1989
# 9        2009
# 10       2010
# 11       2012
# 12       1989
# 13       2009
# 14       2000
# 15       2009
# 16       1998
# 17       2016
# 18       1999
# 19       2007
# 20       2008
# 21       1980
# 22       2008
# 23       2012
# 24       2011
# 25       1996
# 26       2013
# 27       2014
# 28       2003
# 29       1996
#          ...
# 13205    1998
# 13206    2013
# 13207    1997
# 13208    1990
# 13209    1998
# 13210    2014
# 13211    2015
# 13212    2013
# 13213    2000
# 13214    2009
# 13215    2015
# 13216    1980
# 13217    1998
# 13218    2017
# 13219    2015
# 13220    2011
# 13221    1985
# 13222    1998
# 13223    2015
# 13224    1996
# 13225    2000
# 13226    1988
# 13227    1987
# 13228    1998
# 13229    2010
# 13230    2002
# 13231    2016
# 13232    1998
# 13233    2010
# 13234    暂无数据
# ...

# %%
type(l1)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(l1.price)
l1.price.name
# Out:
# 'price'

# %%
l1["orientation"]
# Out:
# 0        南 北
# 1        南 北
# 2          南
# 3        南 北
# 4          南
# 5        南 北
# 6          南
# 7          南
# 8          南
# 9        南 北
# 10         南
# 11       南 北
# 12         南
# 13         南
# 14         南
# 15         南
# 16       南 北
# 17         南
# 18       南 北
# 19         南
# 20       南 北
# 21       南 北
# 22         南
# 23         南
# 24       南 北
# 25       南 北
# 26         南
# 27       南 北
# 28         南
# 29       南 北
#         ...
# 13205      南
# 13206      南
# 13207      南
# 13208      南
# 13209      南
# 13210      南
# 13211      北
# 13212      南
# 13213      南
# 13214     东南
# 13215    南 北
# 13216      南
# 13217    南 北
# 13218      南
# 13219      南
# 13220      南
# 13221      南
# 13222      南
# 13223      北
# 13224     西南
# 13225      南
# 13226      南
# 13227      南
# 13228      北
# 13229      南
# 13230    南 北
# 13231      南
# 13232      西
# 13233      南
# 13234      南
# Name: orientation, Length: 13235, dtype: object

# %%
dd.drop(8)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-214-855391a49a01> in <module>
# ----> 1 dd.drop(8)
#
# c:\users\administrator\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# c:\users\administrator\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
dd
# Out:
#    0  1  2  3  4  dd
# 0  3  6  8  4  1   1
# 1  4  7  1  5  2   2
# 2  7  4  8  2  3   3
# 3  2  8  7  7  4   4
# 4  6  5  8  8  5   5
# 5  9  3  5  9  6   6
# 6  2  5  7  7  7   7

# %%
if 99 in dd.index:
    print(33)

# %%
dd
# Out:
#    0  1  2  3  4  dd
# 0  3  6  8  4  1   1
# 1  4  7  1  5  2   2
# 2  7  4  8  2  3   3
# 3  2  8  7  7  4   4
# 4  6  5  8  8  5   5
# 5  9  3  5  9  6   6
# 6  2  5  7  7  7   7

# %%
dd[dd>3]
# Out:
#        0    1    2    3    4   dd
# 0    NaN  6.0  8.0  4.0  NaN  NaN
# 1    4.0  7.0  NaN  5.0  NaN  NaN
# 2    7.0  4.0  8.0  NaN  NaN  NaN
# 3  999.0  8.0  7.0  7.0  4.0  4.0
# 4    6.0  5.0  8.0  8.0  5.0  5.0
# 5    9.0  NaN  5.0  9.0  6.0  6.0
# 6    NaN  5.0  7.0  7.0  7.0  7.0

# %%
dd.dd[dd.dd>4]= 88

# %%
dd
# Out:
#      0  1  2  3  4  dd
# 0    3  6  8  4  1   1
# 1    4  7  1  5  2   2
# 2    7  4  8  2  3   3
# 3  999  8  7  7  4   4
# 4    6  5  8  8  5   3
# 5    9  3  5  9  6  88
# 6    2  5  7  7  7  88

# %%
pd.concat([dd, dd])
# Out:
#      0  1  2  3  4  dd
# 0    3  6  8  4  1   1
# 1    4  7  1  5  2   2
# 2    7  4  8  2  3   3
# 3  999  8  7  7  4   4
# 4    6  5  8  8  5   3
# 5    9  3  5  9  6  88
# 6    2  5  7  7  7  88
# 0    3  6  8  4  1   1
# 1    4  7  1  5  2   2
# 2    7  4  8  2  3   3
# 3  999  8  7  7  4   4
# 4    6  5  8  8  5   3
# 5    9  3  5  9  6  88
# 6    2  5  7  7  7  88

# %%
aa = dd.iloc[].dd = 999
aa
# Out:
# 999

# %%
a= c=e=3

# %%
e
# Out:
# 3

# %%
l = [ {"name":"dddsf"}, {"name":"dd"},  {"name":"ddfsd"}, 66]
for i in l:
    if type(i) == dict:
        i["name"] = 44
    else:
        i = 99

# %%
l
# Out:
# [{'name': 44}, {'name': 44}, {'name': 44}, 66]

# %%
a = 1
b = 2
c = 3
l = [a, b, c]

# %%
for i in range(len(l)):
    l[i] = l[i]*3

# %%
l
# Out:
# [3, 6, 9]

# %%
a
# Out:
# 1

# %% [markdown]
# ##
